# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/Users/ashwinivalmiki/Downloads'

# %%
df=pd.read_csv('/Users/ashwinivalmiki/Downloads/50_Startups.csv')

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
df['State'].value_counts()
# Out:
# New York      17
# California    17
# Florida       16
# Name: State, dtype: int64

# %%
a=pd.get_dummies(df['State'],drop_first=True)
a
# Out:
#     Florida  New York
# 0         0         1
# 1         0         0
# 2         1         0
# 3         0         1
# 4         1         0
# 5         0         1
# 6         0         0
# 7         1         0
# 8         0         1
# 9         0         0
# 10        1         0
# 11        0         0
# 12        1         0
# 13        0         0
# 14        1         0
# 15        0         1
# 16        0         0
# 17        0         1
# 18        1         0
# 19        0         1
# 20        0         0
# 21        0         1
# 22        1         0
# 23        1         0
# 24        0         1
# 25        0         0
# 26        1         0
# 27        0         1
# 28        1         0
# 29        0         1
# 30        1         0
# 31        0         1
# 32        0         0
# 33        1         0
# 34        0         0
# 35        0         1
# 36        1         0
# 37        0         0
# 38        0         1
# 39        0         0
# ...

# %%
df1=df.drop(['State'],axis=1)

# %%
df1=pd.concat([df1,a],axis=1)
df1
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  Florida  New York
# 0   165349.20       136897.80        471784.10  192261.83        0         1
# 1   162597.70       151377.59        443898.53  191792.06        0         0
# 2   153441.51       101145.55        407934.54  191050.39        1         0
# 3   144372.41       118671.85        383199.62  182901.99        0         1
# 4   142107.34        91391.77        366168.42  166187.94        1         0
# 5   131876.90        99814.71        362861.36  156991.12        0         1
# 6   134615.46       147198.87        127716.82  156122.51        0         0
# 7   130298.13       145530.06        323876.68  155752.60        1         0
# 8   120542.52       148718.95        311613.29  152211.77        0         1
# 9   123334.88       108679.17        304981.62  149759.96        0         0
# 10  101913.08       110594.11        229160.95  146121.95        1         0
# ...

# %%
X= df1.iloc[ : , :-1]

# %%
y=df1.iloc[:,-1]

# %%
# other way
x1=df1.drop(['Profit'],axis=1)
x1
# Out:
#     R&D Spend  Administration  Marketing Spend  Florida  New York
# 0   165349.20       136897.80        471784.10        0         1
# 1   162597.70       151377.59        443898.53        0         0
# 2   153441.51       101145.55        407934.54        1         0
# 3   144372.41       118671.85        383199.62        0         1
# 4   142107.34        91391.77        366168.42        1         0
# 5   131876.90        99814.71        362861.36        0         1
# 6   134615.46       147198.87        127716.82        0         0
# 7   130298.13       145530.06        323876.68        1         0
# 8   120542.52       148718.95        311613.29        0         1
# 9   123334.88       108679.17        304981.62        0         0
# 10  101913.08       110594.11        229160.95        1         0
# 11  100671.96        91790.61        249744.55        0         0
# 12   93863.75       127320.38        249839.44        1         0
# ...

# %%
y1=df1['Profit']
y1
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
df1.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit', 'Florida',
#        'New York'],
#       dtype='object')

# %%
x2=df1[['R&D Spend', 'Administration', 'Marketing Spend', 'Florida','New York']]
y2=df1['Profit']
x2
# Out:
#     R&D Spend  Administration  Marketing Spend  Florida  New York
# 0   165349.20       136897.80        471784.10        0         1
# 1   162597.70       151377.59        443898.53        0         0
# 2   153441.51       101145.55        407934.54        1         0
# 3   144372.41       118671.85        383199.62        0         1
# 4   142107.34        91391.77        366168.42        1         0
# 5   131876.90        99814.71        362861.36        0         1
# 6   134615.46       147198.87        127716.82        0         0
# 7   130298.13       145530.06        323876.68        1         0
# 8   120542.52       148718.95        311613.29        0         1
# 9   123334.88       108679.17        304981.62        0         0
# 10  101913.08       110594.11        229160.95        1         0
# 11  100671.96        91790.61        249744.55        0         0
# 12   93863.75       127320.38        249839.44        1         0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x2, y2, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#     R&D Spend  Administration  Marketing Spend  Florida  New York
# 46    1315.46       115816.21        297114.46        1         0
# 47       0.00       135426.92             0.00        0         0
# 15  114523.61       122616.84        261776.23        0         1
# 9   123334.88       108679.17        304981.62        0         0
# 16   78013.11       121597.55        264346.06        0         0
# 24   77044.01        99281.34        140574.81        0         1
# 34   46426.07       157693.92        210797.67        0         0
# 31   61136.38       152701.92         88218.23        0         1
# 0   165349.20       136897.80        471784.10        0         1
# 44   22177.74       154806.14         28334.72        0         0
# 27   72107.60       127864.55        353183.81        0         1
# 33   55493.95       103057.49        214634.81        1         0
# 5   131876.90        99814.71        362861.36        0         1
# ...

# %%
y_train
# Out:
# 46     49490.75
# 47     42559.73
# 15    129917.04
# 9     149759.96
# 16    126992.93
# 24    108552.04
# 34     96712.80
# 31     97483.56
# 0     192261.83
# 44     65200.33
# 27    105008.31
# 33     96778.92
# 5     156991.12
# 29    101004.64
# 11    144259.40
# 36     90708.19
# 1     191792.06
# 21    111313.02
# 2     191050.39
# 43     69758.98
# 35     96479.51
# 23    108733.99
# 40     78239.91
# 10    146121.95
# 22    110352.25
# 18    124266.90
# 49     14681.40
# 20    118474.03
# 7     155752.60
# 42     71498.49
# 14    132602.65
# 28    103282.38
# 38     81229.06
# Name: Profit, dtype: float64

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((33, 5), (17, 5), (33,), (17,))

# %%
df1.shape
# Out:
# (50, 6)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#y=m1x1+m2x2+m3x3+m4x4+m5x5+c is the model

# %%
reg.coef_
# Out:
# array([ 8.04312540e-01, -8.99140461e-02,  2.84812890e-02,  4.03924487e+02,
#        -1.21407965e+03])

# %%
reg.intercept_
# Out:
# 57183.41295217197

# %%
y_train_pred=reg.predict(X_train)
y_train_pred
# Out:
# array([ 56694.07716541,  45006.63062018, 144512.857242  , 155297.68934747,
#        116525.92444407, 113013.76150971,  86349.3742125 ,  93924.61183384,
#        190089.75258858,  61909.01028595, 112528.69135221,  99068.57747849,
#        163399.5925741 ,  98028.35104457, 137014.91440024,  74946.17221837,
#        186994.61279621, 113729.48015644, 183526.36401409,  57999.3873584 ,
#         91185.43447747, 111076.30148411,  74573.36956591, 136140.14104102,
#        114701.11961731, 129516.0196457 ,  47951.5131393 , 116783.42821569,
#        158526.98617222,  71764.57297254, 147289.19615997,  97656.01500381,
#         71587.18986212])

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
mean_squared_error(y_train,y_train_pred)
# Out:
# 86483868.1070793

# %%
#finding accuracy for training point

# %%
r2_score(y_train,y_train_pred)*100 # 94% of training accuracy
# Out:
# 94.83841429755522

# %%
X_data=pd.DataFrame({'Actual':y_train,'y_predicted':y_train_pred})

# %%
X_data
# Out:
#        Actual    y_predicted
# 46   49490.75   56694.077165
# 47   42559.73   45006.630620
# 15  129917.04  144512.857242
# 9   149759.96  155297.689347
# 16  126992.93  116525.924444
# 24  108552.04  113013.761510
# 34   96712.80   86349.374212
# 31   97483.56   93924.611834
# 0   192261.83  190089.752589
# 44   65200.33   61909.010286
# 27  105008.31  112528.691352
# 33   96778.92   99068.577478
# 5   156991.12  163399.592574
# 29  101004.64   98028.351045
# 11  144259.40  137014.914400
# 36   90708.19   74946.172218
# 1   191792.06  186994.612796
# 21  111313.02  113729.480156
# 2   191050.39  183526.364014
# 43   69758.98   57999.387358
# 35   96479.51   91185.434477
# 23  108733.99  111076.301484
# 40   78239.91   74573.369566
# 10  146121.95  136140.141041
# 22  110352.25  114701.119617
# 18  124266.90  129516.019646
# 49   14681.40   47951.513139
# 20  118474.03  116783.428216
# 7   155752.60  158526.986172
# 42   71498.49   71764.572973
# 14  132602.65  147289.196160
# ...

# %%
# Testing part
y_test_pred=reg.predict(X_test)

# %%
X_test=pd.DataFrame({'Actual':y_test,'Predicted':y_test_pred})

# %%
X_test
# Out:
#        Actual      Predicted
# 13  134307.35  126187.358759
# 39   81005.76   85719.456250
# 30   99937.59   99648.034932
# 45   64926.08   45664.955053
# 17  125370.37  127106.842490
# 48   35673.41   51752.874942
# 26  105733.54  109033.361857
# 25  107404.34  100575.614106
# 32   97427.84   97877.863567
# 19  122776.86  111674.706978
# 12  141585.52  128750.987418
# 4   166187.94  174097.597840
# 37   89949.14   93630.003624
# 8   152211.77  148426.419420
# 3   182901.99  172333.626070
# 6   156122.51  155858.609223
# 41   77798.83   77089.612523

# %%
mean_squared_error(y_test,y_test_pred)
# Out:
# 74658919.97269887

# %%
r2_score(y_test,y_test_pred)*100
# Out:
# 94.75312056928277

# %%
reg.coef_
# Out:
# array([ 8.04312540e-01, -8.99140461e-02,  2.84812890e-02,  4.03924487e+02,
#        -1.21407965e+03])

# %%
reg.intercept_
# Out:
# 57183.41295217197

# %%
reg.predict([[12.2,15.5,20,0,0]])
# Out:
# /Users/ashwinivalmiki/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([57192.40152323])

# %%
#y=m1x1+m2x2+m3x3+m4x4+m5x5+c

# %%
y=(8.04312540e-01* 12.2)+(-8.99140461e-02*15.5)+(2.84812890e-02*20)+(4.03924487e+02*0)+(-1.21407965e+03*0)+57183.41295217197

# %%
y
# Out:
# 57192.401523225424
